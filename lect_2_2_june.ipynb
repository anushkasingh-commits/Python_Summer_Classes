# %%
s = input()
i = 0
j = len(s) - 1

while (i < j):
  if s[i] != s[j]:
    print("Not Pallindrome")
    break
  i += 1
  j -= 1
else :
  print("Pallindrome")
# Out:
# NIGHT
# Not Pallindrome

# %%
#List

lst = [i, 2, "hello", 'c', [4, 5]]
print(lst)

#append()
lst.append([5, 6])
print(lst)

#extend()
lst.extend([5, 6])
print(lst)

#insert()
lst.insert(2, "anushka")
print(lst)
# Out:
# [0, 2, 'hello', 'c', [4, 5]]
# [0, 2, 'hello', 'c', [4, 5], [5, 6]]
# [0, 2, 'hello', 'c', [4, 5], [5, 6], 5, 6]
# [0, 2, 'anushka', 'hello', 'c', [4, 5], [5, 6], 5, 6]

# %%
lst = [1, 4, 6, 'a']
print(lst)

lst.append(['w', 2])
print(lst)

lst.extend([2, 3])
print(lst)

lst.insert(1, "anushka")
print(lst)
# Out:
# [1, 4, 6, 'a']
# [1, 4, 6, 'a', ['w', 2]]
# [1, 4, 6, 'a', ['w', 2], 2, 3]
# [1, 'anushka', 4, 6, 'a', ['w', 2], 2, 3]

# %%
lst = [1, 4, 6, 'a']
print(lst)

#pop()
lst.pop()
print(lst)
# Out:
# [1, 4, 6, 'a']
# [1, 4, 6]

# %%
lst = [1, 4, 4, 6, 'a']
print(lst)

#remove()
lst.remove(4)
print(lst)
# Out:
# [1, 4, 4, 6, 'a']
# [1, 4, 6, 'a']

# %%
lst = [1, 4, 4, 6, 'a']
print(lst)

#index()
print(lst.index(6))

#count()
print(lst.count(4))
# Out:
# [1, 4, 4, 6, 'a']
# 3
# 2

# %%
lst = [3, 1, 6, 4]
print(lst)

#sort()
lst.sort()
print(lst)
# Out:
# [3, 1, 6, 4]
# [1, 3, 4, 6]

# %%
lst = [1, 3, 8, 4]
print(lst)

#sum
print(sum(lst))

#max
print(max(lst))

#min
print(min(lst))

#sorted
a = sorted(lst)
print(a)
# Out:
# [1, 3, 8, 4]
# 16
# 8
# 1
# [1, 3, 4, 8]

# %%
#Tuples

tp = (1, 4, 8, 2)
print(tp)

a = tuple(sorted(tp))
print(a)
# Out:
# (1, 4, 8, 2)
# (1, 2, 4, 8)

# %%
tp = (1, 4, 8, 8, 2)
print(tp)

#sum
print(sum(tp))

#max
print(max(tp))

#min
print(min(tp))

#index
print(tp.index(4))

#len
print(len(tp))

#count
print(tp.count(8))
# Out:
# (1, 4, 8, 8, 2)
# 23
# 8
# 1
# 1
# 5
# 2

# %%
lst1 = []
lst2 = []

n = int(input())
print("Enter elements: ")
for i in range(n):
  x = int(input())
  lst1.append(x)

print("Enter elements: ")
for i in range(n):
  x = int(input())
  lst2.append(x)

result = []
for i in range(n):
  result.append(lst1[i]+lst2[i])
print(result)
# Out:
# 4
# Enter elements:
# 1
# 2
# 3
# 4
# Enter elements:
# 5
# 6
# 7
# 8
# [6, 8, 10, 12]
